# %%
from ex4 import ex4
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %%
im = np.asarray(Image.open('a000.jpg'), dtype = np.float32)

# %%
plt.imshow(im)
plt.show()

# %%
crop_size = (501,1131)
crop_center = (1000,830)

# %%
image_array, crop_array, target_array = ex4(im, crop_size, crop_center)

# %%
plt.imshow(image_array)
plt.title('image_array')
plt.show()

plt.imshow(crop_array)
plt.title('crop_array')
plt.show()

plt.imshow(target_array)
plt.title('target_array')
plt.show()

# %%
im.shape
# Out:
# (1887, 1415)

# %%
1887-1
# Out:
# 1886

# %%
1886-20
# Out:
# 1866
